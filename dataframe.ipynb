# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'name' : ['사과','딸기','수박'],
    'price' : [1800,1500,3000], 
    'num' : [24,38,13]})
df
# Out:
#   name  price  num
# 0   사과   1800   24
# 1   딸기   1500   38
# 2   수박   3000   13

# %%
df.to_csv('maked_csv.csv',index=False)

# %%
print("가격 평균 : ", sum(df["price"])/len(df["price"]), "\n판매량 평균 : ",sum(df["num"])/len(df["num"]))
# Out:
# 가격 평균 :  2100.0
# 판매량 평균 :  25.0

# %%
sum(df['english'])
# Out:
# 300

# %%
sum(df['english']) / len(df['english'])
# Out:
# 75.0

# %% [markdown]
# <h1>엑셀 불러오기</h1>

# %%
df_exam = pd.read_excel('excel_exam.xlsx')
df_exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %% [markdown]
# <h1>csv파일</h1>

# %%
df_csv = pd.read_csv("csv.csv")
df_csv.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50     98.0       50
# 1   2       1    60     97.0       60
# 2   3       1    45     86.0       78
# 3   4       1    30     98.0       58
# 4   5       2    25     80.0       65

# %%
df_csv.tail()
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_csv.shape
# Out:
# (20, 5)

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  19 non-null     float64
#  4   science  20 non-null     int64
# dtypes: float64(1), int64(4)
# memory usage: 928.0 bytes

# %%
mpg.shape
# Out:
# (234, 11)

# %%
df_csv.describe(include='all')
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  19.000000  20.000000
# mean   10.50000   3.000000  57.450000  85.947368  59.450000
# std     5.91608   1.450953  20.299015  12.321948  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  79.000000  45.000000
# 50%    10.50000   3.000000  54.000000  87.000000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %% [markdown]
# <h1>실습 mpg</h1>

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.describe(include='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %% [markdown]
# <h1>변수명 바꾸기</h1>

# %%
df_raw = pd.DataFrame({
    'var1' : [1,2,1],
    'var2' : [2,3,4]
    })
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     4

# %%
df_new = df_raw.rename(columns={'var2' : 'v2'})
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   4

# %%
mpg_copy = mpg.copy()
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg_copy = mpg_copy.rename(columns={'cty' : 'city', 'hwy' : 'highway'})
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     category
# 0    compact
# 1    compact
# ...

# %%
df = pd.DataFrame({
    'var1' : [4,3,8],
    'var2' : [2,6,1]
    })
df['var_sum'] = df["var1"] + df['var2']
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     category
# 0    compact
# 1    compact
# ...

# %%
mpg_copy['total'] = (mpg_copy['city'] + mpg_copy['highway']) /2
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     category  total
# 0    compact   23.5
# ...

# %%
mpg_copy['total'].mean()
# Out:
# 20.14957264957265

# %%
mpg_copy['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg = mpg_copy

# %%
mpg['total'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
import numpy as np

# %%
mpg['test'] = np.where(mpg['total']>=20, 'pass','fail')

# %%
mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
count_test = mpg['test'].value_counts()
count_test.plot.bar(rot=0)
# Out:
# <AxesSubplot: >

# %%
mpg['grade'] = np.where(mpg['total']>=30,'A',
                        np.where(mpg['total']>=20,'B','C'))
mpg['grade'].value_counts()
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
grade = mpg['grade'].value_counts().sort_index()
grade.plot.bar(rot = 0)
# Out:
# <AxesSubplot: >

# %%
mpg['size'] = np.where((mpg['category'] == 'compact')|
                        (mpg['category'] == 'subcompact')|
                        (mpg['category'] == '2seater'),
                        'small','large'
)
size = mpg['size'].value_counts().sort_index()
size.plot.bar(rot=0)
# Out:
# <AxesSubplot: >

# %% [markdown]
# <h1>midewest(미국 동북중부 인구 통계정보) 실습</h1>

# %%
mid = pd.read_csv('midwest.csv')
mid.shape
# Out:
# (437, 28)

# %%
mid.head()
# Out:
#    PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022     14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018      5836   324.222222      5264       547
#
#    popamerindian  popasian  ...  percollege  percprof  poppovertyknown  \
# 0             98       249  ...   19.631392  4.355859            63628
# 1             19        48  ...   11.243308  2.870315            10529
# 2             35        16  ...   17.033819  4.488572            14235
# 3             46       150  ...   17.278954  4.197800            30337
# 4             14         5  ...   14.475999  3.367680             4815
#
#    percpovertyknown  percbelowpoverty  percchildbelowpovert  percadultpoverty  \
# ...

# %%
mid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 437 entries, 0 to 436
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PID                   437 non-null    int64
#  1   county                437 non-null    object
#  2   state                 437 non-null    object
#  3   area                  437 non-null    float64
#  4   poptotal              437 non-null    int64
#  5   popdensity            437 non-null    float64
#  6   popwhite              437 non-null    int64
#  7   popblack              437 non-null    int64
#  8   popamerindian         437 non-null    int64
#  9   popasian              437 non-null    int64
#  10  popother              437 non-null    int64
#  11  percwhite             437 non-null    float64
#  12  percblack             437 non-null    float64
#  13  percamerindan         437 non-null    float64
#  14  percasian             437 non-null    float64
# ...

# %%
mid.describe(include='all')
# Out:
#                 PID  county state        area      poptotal    popdensity  \
# count    437.000000     437   437  437.000000  4.370000e+02    437.000000
# unique          NaN     320     5         NaN           NaN           NaN
# top             NaN  MONROE    IL         NaN           NaN           NaN
# freq            NaN       5   102         NaN           NaN           NaN
# mean    1437.338673     NaN   NaN    0.033169  9.613030e+04   3097.742985
# std      876.390266     NaN   NaN    0.014679  2.981705e+05   7664.751786
# min      561.000000     NaN   NaN    0.005000  1.701000e+03     85.050000
# 25%      670.000000     NaN   NaN    0.024000  1.884000e+04    622.407407
# 50%     1221.000000     NaN   NaN    0.030000  3.532400e+04   1156.208330
# 75%     2059.000000     NaN   NaN    0.038000  7.565100e+04   2330.000000
# max     3052.000000     NaN   NaN    0.110000  5.105067e+06  88018.396600
#
#             popwhite      popblack  popamerindian       popasian  ...  \
# ...

# %%
mid = mid.rename(columns={'poptotal' : 'total','popasian' : 'asian'})
mid.head()
# Out:
#    PID     county state   area  total   popdensity  popwhite  popblack  \
# 0  561      ADAMS    IL  0.052  66090  1270.961540     63917      1702
# 1  562  ALEXANDER    IL  0.014  10626   759.000000      7054      3496
# 2  563       BOND    IL  0.022  14991   681.409091     14477       429
# 3  564      BOONE    IL  0.017  30806  1812.117650     29344       127
# 4  565      BROWN    IL  0.018   5836   324.222222      5264       547
#
#    popamerindian  asian  ...  percollege  percprof  poppovertyknown  \
# 0             98    249  ...   19.631392  4.355859            63628
# 1             19     48  ...   11.243308  2.870315            10529
# 2             35     16  ...   17.033819  4.488572            14235
# 3             46    150  ...   17.278954  4.197800            30337
# 4             14      5  ...   14.475999  3.367680             4815
#
#    percpovertyknown  percbelowpoverty  percchildbelowpovert  percadultpoverty  \
# ...

# %%
mid['asian per total'] = mid['asian'] / mid['total'] *100
mid['asian per total'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
a_mean = mid['asian per total'].mean()

# %%
mid['asia_percent'] = np.where(mid['asian per total'] >=a_mean, 'large','small')
mid['asia_percent'].value_counts()
# Out:
# small    318
# large    119
# Name: asia_percent, dtype: int64

# %%
count = mid['asia_percent'].value_counts()
count.plot.bar(rot=0)
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
exam = pd.read_csv('exam.csv')
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
exam.shape
# Out:
# (20, 5)

# %%
exam['nclass'].value_counts()
# Out:
# 1    4
# 2    4
# 3    4
# 4    4
# 5    4
# Name: nclass, dtype: int64

# %%
exam.query('nclass != 3')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math>50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('math > 50 & nclass ==1')
# Out:
#    id  nclass  math  english  science
# 1   2       1    60       97       60

# %%
exam.query('math >=90 | english >=90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
exam.query('nclass in [1,2,3]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#     category  total  test grade   size
# ...

# %%
displ4 = mpg.query('displ <=4')
displ4['highway'].mean()
# Out:
# 25.96319018404908

# %%
displ5 = mpg.query('displ >= 5')
displ5['highway'].mean()
# Out:
# 18.07894736842105

# %%
audi = mpg.query('manufacturer == "audi"')
toyota = mpg.query('manufacturer == "toyota"')

# %%
audi['city'].mean()
# Out:
# 17.61111111111111

# %%
toyota['city'].mean()
# Out:
# 18.529411764705884

# %%
three = mpg.query('manufacturer in ["chevrolet","ford","honda"]')
three['highway'].mean()
# Out:
# 22.50943396226415

# %% [markdown]
# <h1>필요한 변수만 추출하기</h1>

# %%
exam[['math','english']]
# Out:
#     math  english
# 0     50       98
# 1     60       97
# 2     45       86
# 3     30       98
# 4     25       80
# 5     50       89
# 6     80       90
# 7     90       78
# 8     20       98
# 9     50       98
# 10    65       65
# 11    45       85
# 12    46       98
# 13    48       87
# 14    75       56
# 15    58       98
# 16    65       68
# 17    80       78
# 18    89       68
# 19    78       83

# %%
exam.drop(columns='math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.query('math>50')\
[['english']]\
.head()
# Out:
#     english
# 1        97
# 6        90
# 7        78
# 10       65
# 14       56

# %%
new_data = mpg[['category','city']]
new_data.head()
# Out:
#   category  city
# 0  compact    18
# 1  compact    21
# 2  compact    20
# 3  compact    21
# 4  compact    16

# %%
suv = new_data.query('category in ["suv"]')
suv['city'].mean()
# Out:
# 13.5

# %%
compact = new_data.query('category in ["compact"]')
compact['city'].mean()
# Out:
# 20.127659574468087

# %%
exam.sort_values('math',ascending=False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values(['nclass','math'], ascending=[True, False])
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %%
audi = mpg.query('manufacturer == "audi"')
audi.sort_values('highway', ascending=False).head(5)
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f    20       31
# 3         audi          a4    2.0  2008    4    auto(av)   f    21       30
# 0         audi          a4    1.8  1999    4    auto(l5)   f    18       29
# 1         audi          a4    1.8  1999    4  manual(m5)   f    21       29
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4    20       28
#
#   fl category  total  test grade   size
# 2  p  compact   25.5  pass     B  small
# 3  p  compact   25.5  pass     B  small
# 0  p  compact   23.5  pass     B  small
# 1  p  compact   25.0  pass     B  small
# 9  p  compact   24.0  pass     B  small

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['total'] = exam['math'] + exam['english'] + exam['science']

# %%
exam.drop('total')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [191], line 1
# ----> 1 exam.drop('total')
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
exam.assign(total = exam['math'] + exam['english']+ exam['science'],
mean = (exam['math'] + exam['english']+ exam['science'])/3).sort_values('total',ascending=False)
# Out:
#     id  nclass  math  english  science  total       mean
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 5    6       2    50       89       98    237  79.000000
# 16  17       5    65       68       98    231  77.000000
# 15  16       4    58       98       65    221  73.666667
# 19  20       5    78       83       58    219  73.000000
# 1    2       1    60       97       60    217  72.333333
# 6    7       2    80       90       45    215  71.666667
# 12  13       4    46       98       65    209  69.666667
# 2    3       1    45       86       78    209  69.666667
# 14  15       4    75       56       78    209  69.666667
# 0    1       1    50       98       50    198  66.000000
# 10  11       3    65       65       65    195  65.000000
# 9   10       3    50       98       45    193  64.333333
# 7    8       2    90       78       25    193  64.333333
# ...

# %%
exam.assign(test = np.where(exam['science']>=60,'pass','fail'))
# Out:
#     id  nclass  math  english  science  total  test
# 0    1       1    50       98       50    198  fail
# 1    2       1    60       97       60    217  pass
# 2    3       1    45       86       78    209  pass
# 3    4       1    30       98       58    186  fail
# 4    5       2    25       80       65    170  pass
# 5    6       2    50       89       98    237  pass
# 6    7       2    80       90       45    215  fail
# 7    8       2    90       78       25    193  fail
# 8    9       3    20       98       15    133  fail
# 9   10       3    50       98       45    193  fail
# 10  11       3    65       65       65    195  pass
# 11  12       3    45       85       32    162  fail
# 12  13       4    46       98       65    209  pass
# 13  14       4    48       87       12    147  fail
# 14  15       4    75       56       78    209  pass
# 15  16       4    58       98       65    221  pass
# 16  17       5    65       68       98    231  pass
# ...

# %%
long_name = pd.read_csv('exam.csv')

# long_name.assign(new = long_name['math']+ long_name['english']+ long_name['science'])

long_name = long_name.assign(new = lambda x:x['math'] + x['english']+ x['science'])
long_name
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %%
exam = pd.read_csv('exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.assign(total = lambda x : x['math']+x['english']+ x['science'],
mean = lambda x: x['total']/3).sort_values(['total','mean'], ascending=[True, False])
# Out:
#     id  nclass  math  english  science  total       mean
# 8    9       3    20       98       15    133  44.333333
# 13  14       4    48       87       12    147  49.000000
# 11  12       3    45       85       32    162  54.000000
# 4    5       2    25       80       65    170  56.666667
# 3    4       1    30       98       58    186  62.000000
# 7    8       2    90       78       25    193  64.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 0    1       1    50       98       50    198  66.000000
# 2    3       1    45       86       78    209  69.666667
# 12  13       4    46       98       65    209  69.666667
# 14  15       4    75       56       78    209  69.666667
# 6    7       2    80       90       45    215  71.666667
# 1    2       1    60       97       60    217  72.333333
# 19  20       5    78       83       58    219  73.000000
# ...

# %%
mpg = pd.read_csv('mpg.csv')
mpg_copy = mpg.copy()

# %%
mpg_copy = mpg_copy.assign(total = lambda x : x['cty'] + x['hwy'],
mean = lambda x :  x['total']/2)
mpg_copy.sort_values(['mean'], ascending=False).head(3)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category  total  mean
# 221  subcompact     79  39.5
# 212     compact     77  38.5
# 222  subcompact     70  35.0

# %%
mpg.assign(total = lambda x : x['cty'] + x['hwy'],
mean = lambda x :  x['total']/2).sort_values(['mean'], ascending=False).head(3)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category  total  mean
# 221  subcompact     79  39.5
# 212     compact     77  38.5
# 222  subcompact     70  35.0

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.agg(mean_math = ('math', 'mean'))
# Out:
#             math
# mean_math  57.45

# %%
exam.groupby('nclass',as_index=False).agg(
    mean_math=('math','mean'),
    sum_math = ('math', 'sum'),
    median_math = ('math','median'),
    n = ('nclass','count')
    )
# Out:
#    nclass  mean_math  sum_math  median_math  n
# 0       1      46.25       185         47.5  4
# 1       2      61.25       245         65.0  4
# 2       3      45.00       180         47.5  4
# 3       4      56.75       227         53.0  4
# 4       5      78.00       312         79.0  4

# %%
exam.groupby('nclass').mean()
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg = pd.read_csv('mpg.csv')

# %%
mpg.query('category == "suv"')\
    .assign(total = (mpg['cty']+mpg['hwy'])/2)\
        .groupby('manufacturer')\
            .agg(total_mean=('total','mean'))\
                .sort_values('total_mean', ascending=False)\
                    .head(5)
# Out:
#               total_mean
# manufacturer
# subaru         21.916667
# toyota         16.312500
# nissan         15.875000
# mercury        15.625000
# jeep           15.562500

# %%
mpg.groupby('category').agg(cty_mean = ('cty','mean')).sort_values('cty_mean', ascending=False)
# Out:
#              cty_mean
# category
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %%
mpg.groupby('manufacturer').agg(hwy_mean = ('hwy','mean')).sort_values('hwy_mean',ascending=False).head(3)
# Out:
#                hwy_mean
# manufacturer
# honda         32.555556
# volkswagen    29.222222
# hyundai       26.857143

# %%
mpg.query('category == "compact"').groupby('manufacturer').agg(n = ('category','count')).sort_values('n')
# Out:
#                n
# manufacturer
# nissan         2
# subaru         4
# toyota        12
# volkswagen    14
# audi          15

# %%
test1 = pd.DataFrame({
    'id' : [1,2,3,4,5],
    'midterm' : [60,80,70,90,85],
})

test2 = pd.DataFrame({
    'id' : [1,2,3,4,5],
    'final' : [70,83,65,95,80]
})

total = pd.merge(test1, test2, how = 'left', on='id')
total
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
name = pd.DataFrame({
    'nclass' : [1,2,3,4,5],
    'teacher' : ["jisu","jiho","dabin","sukho","ace"],
})
name
# Out:
#    nclass teacher
# 0       1    jisu
# 1       2    jiho
# 2       3   dabin
# 3       4   sukho
# 4       5     ace

# %%
exam_new = pd.merge(exam, name, how='left', on = 'nclass')
exam_new
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50    jisu
# 1    2       1    60       97       60    jisu
# 2    3       1    45       86       78    jisu
# 3    4       1    30       98       58    jisu
# 4    5       2    25       80       65    jiho
# 5    6       2    50       89       98    jiho
# 6    7       2    80       90       45    jiho
# 7    8       2    90       78       25    jiho
# 8    9       3    20       98       15   dabin
# 9   10       3    50       98       45   dabin
# 10  11       3    65       65       65   dabin
# 11  12       3    45       85       32   dabin
# 12  13       4    46       98       65   sukho
# 13  14       4    48       87       12   sukho
# 14  15       4    75       56       78   sukho
# 15  16       4    58       98       65   sukho
# 16  17       5    65       68       98     ace
# 17  18       5    80       78       90     ace
# 18  19       5    89       68       87     ace
# ...

# %%
group_a = pd.DataFrame({
    'id' : [1,2,3,4,5],
    'test' : [60,80,70,90,85]
})

group_b = pd.DataFrame({
    'id' : [6,7,8,9,10],
    'test' : [10,2,30,40,50],
})

# %%
group_a
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85

# %%
group_all = pd.concat([group_a, group_b], ignore_index=True)
group_all
# Out:
#    id  test
# 0   1    60
# 1   2    80
# 2   3    70
# 3   4    90
# 4   5    85
# 5   6    10
# 6   7     2
# 7   8    30
# 8   9    40
# 9  10    50

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
fuel = pd.DataFrame({
    'fl' : ['c','d','e','p','r'],
'price_fl' : [2.35,2.38,2.11,2.76,2.22]
})

# %%
mpg_merge = pd.merge(mpg,fuel, how = 'left', on ='fl')
mpg_merge
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  price_fl
# 0    compact      2.76
# 1    compact      2.76
# 2    compact      2.76
# ...

# %%
mpg_merge[["model","fl","price_fl"]].head(3)
# Out:
#   model fl  price_fl
# 0    a4  p      2.76
# 1    a4  p      2.76
# 2    a4  p      2.76

# %%
mid = pd.read_csv('midwest.csv')
mid
# Out:
#       PID     county state   area  poptotal   popdensity  popwhite  popblack  \
# 0     561      ADAMS    IL  0.052     66090  1270.961540     63917      1702
# 1     562  ALEXANDER    IL  0.014     10626   759.000000      7054      3496
# 2     563       BOND    IL  0.022     14991   681.409091     14477       429
# 3     564      BOONE    IL  0.017     30806  1812.117650     29344       127
# 4     565      BROWN    IL  0.018      5836   324.222222      5264       547
# ..    ...        ...   ...    ...       ...          ...       ...       ...
# 432  3048   WAUKESHA    WI  0.034    304715  8962.205880    298313      1096
# 433  3049    WAUPACA    WI  0.045     46104  1024.533330     45695        22
# 434  3050   WAUSHARA    WI  0.037     19385   523.918919     19094        29
# 435  3051  WINNEBAGO    WI  0.035    140320  4009.142860    136822       697
# 436  3052       WOOD    WI  0.048     73605  1533.437500     72157        90
#
# ...

# %%
mid= mid.assign(non_adults_per_total = (mid['poptotal'] - mid['popadults']) / mid['poptotal']*100)

# %%
mid[['county','non_adults_per_total']].sort_values('non_adults_per_total',ascending=False).head(5)
# Out:
#         county  non_adults_per_total
# 230   ISABELLA             51.501172
# 404  MENOMINEE             50.591260
# 281     ATHENS             49.320727
# 247    MECOSTA             49.059183
# 154     MONROE             47.358182

# %%
mid = mid.assign(rate = np.where(mid['non_adults_per_total'] >= 40,'large',
np.where(mid['non_adults_per_total'] >= 30,'middle','small')))

# %%
# mid.value_counts('rate').sort_index()
mid.groupby('rate').agg(n = ('rate','count'))
# Out:
#           n
# rate
# large    32
# middle  396
# small     9

# %%
mid.value_counts('rate').sort_index(ascending=False).plot.bar(rot=0)
# Out:
# <AxesSubplot: xlabel='rate'>

# %%
mid
# Out:
#     state     county  asian_per_total
# 404    WI  MENOMINEE         0.000000
# 105    IN     BENTON         0.010592
# 109    IN    CARROLL         0.015950
# 358    OH     VINTON         0.027032
# 390    WI       IRON         0.032504
# 85     IL      SCOTT         0.053154
# 112    IN       CLAY         0.060716
# 261    MI     OSCODA         0.063759
# 340    OH      PERRY         0.066546
# 73     IL      PIATT         0.070749

# %%
mid.assign(asian_per_total = mid['popasian'] / mid['poptotal']*100)\
    .sort_values('asian_per_total')\
    .head(10)\
    [['state','county','asian_per_total']]
# Out:
#     state     county  asian_per_total
# 404    WI  MENOMINEE         0.000000
# 105    IN     BENTON         0.010592
# 109    IN    CARROLL         0.015950
# 358    OH     VINTON         0.027032
# 390    WI       IRON         0.032504
# 85     IL      SCOTT         0.053154
# 112    IN       CLAY         0.060716
# 261    MI     OSCODA         0.063759
# 340    OH      PERRY         0.066546
# 73     IL      PIATT         0.070749

# %%
mid[['state','county','asian_per_total']].head(10)
# Out:
#     state     county  asian_per_total
# 404    WI  MENOMINEE         0.000000
# 105    IN     BENTON         0.010592
# 109    IN    CARROLL         0.015950
# 358    OH     VINTON         0.027032
# 390    WI       IRON         0.032504
# 85     IL      SCOTT         0.053154
# 112    IN       CLAY         0.060716
# 261    MI     OSCODA         0.063759
# 340    OH      PERRY         0.066546
# 73     IL      PIATT         0.070749
